# %% [markdown]
# # Springboard Data Science Career Track Unit 4 Challenge - Tier 3 Complete
#
# ## Objectives
# Hey! Great job getting through those challenging DataCamp courses. You're learning a lot in a short span of time.
#
# In this notebook, you're going to apply the skills you've been learning, bridging the gap between the controlled environment of DataCamp and the *slightly* messier work that data scientists do with actual datasets!
#
# Here’s the mystery we’re going to solve: ***which boroughs of London have seen the greatest increase in housing prices, on average, over the last two decades?***
#
#
# A borough is just a fancy word for district. You may be familiar with the five boroughs of New York… well, there are 32 boroughs within Greater London [(here's some info for the curious)](https://en.wikipedia.org/wiki/London_boroughs). Some of them are more desirable areas to live in, and the data will reflect that with a greater rise in housing prices.
#
# ***This is the Tier 3 notebook, which means it's not filled in at all: we'll just give you the skeleton of a project, the brief and the data. It's up to you to play around with it and see what you can find out! Good luck! If you struggle, feel free to look at easier tiers for help; but try to dip in and out of them, as the more independent work you do, the better it is for your learning!***
#
# This challenge will make use of only what you learned in the following DataCamp courses:
# - Prework courses (Introduction to Python for Data Science, Intermediate Python for Data Science)
# - Data Types for Data Science
# - Python Data Science Toolbox (Part One)
# - pandas Foundations
# - Manipulating DataFrames with pandas
# - Merging DataFrames with pandas
#
# Of the tools, techniques and concepts in the above DataCamp courses, this challenge should require the application of the following:
# - **pandas**
#     - **data ingestion and inspection** (pandas Foundations, Module One)
#     - **exploratory data analysis** (pandas Foundations, Module Two)
#     - **tidying and cleaning** (Manipulating DataFrames with pandas, Module Three)
#     - **transforming DataFrames** (Manipulating DataFrames with pandas, Module One)
#     - **subsetting DataFrames with lists** (Manipulating DataFrames with pandas, Module One)
#     - **filtering DataFrames** (Manipulating DataFrames with pandas, Module One)
#     - **grouping data** (Manipulating DataFrames with pandas, Module Four)
#     - **melting data** (Manipulating DataFrames with pandas, Module Three)
#     - **advanced indexing** (Manipulating DataFrames with pandas, Module Four)
# - **matplotlib** (Intermediate Python for Data Science, Module One)
# - **fundamental data types** (Data Types for Data Science, Module One)
# - **dictionaries** (Intermediate Python for Data Science, Module Two)
# - **handling dates and times** (Data Types for Data Science, Module Four)
# - **function definition** (Python Data Science Toolbox - Part One, Module One)
# - **default arguments, variable length, and scope** (Python Data Science Toolbox - Part One, Module Two)
# - **lambda functions and error handling** (Python Data Science Toolbox - Part One, Module Four)

# %%
import os
print(os.getcwd())
# Out:
# /Users/huiyuanzhao

# %% [markdown]
# ## The Data Science Pipeline
#
# This is Tier Three, so we'll get you started. But after that, it's all in your hands! When you feel done with your investigations, look back over what you've accomplished, and prepare a quick presentation of your findings for the next mentor meeting.
#
# Data Science is magical. In this case study, you'll get to apply some complex machine learning algorithms. But as  [David Spiegelhalter](https://www.youtube.com/watch?v=oUs1uvsz0Ok) reminds us, there is no substitute for simply **taking a really, really good look at the data.** Sometimes, this is all we need to answer our question.
#
# Data Science projects generally adhere to the four stages of Data Science Pipeline:
# 1. Sourcing and loading
# 2. Cleaning, transforming, and visualizing
# 3. Modeling
# 4. Evaluating and concluding

# %% [markdown]
# ### 1. Sourcing and Loading
#
# Any Data Science project kicks off by importing  ***pandas***. The documentation of this wonderful library can be found [here](https://pandas.pydata.org/). As you've seen, pandas is conveniently connected to the [Numpy](http://www.numpy.org/) and [Matplotlib](https://matplotlib.org/) libraries.
#
# ***Hint:*** This part of the data science pipeline will test those skills you acquired in the pandas Foundations course, Module One.

# %% [markdown]
# #### 1.1. Importing Libraries

# %%
# Let's import the pandas, numpy libraries as pd, and np respectively. 
import pandas as pd
import numpy as np

# Load the pyplot collection of functions from matplotlib, as plt 
import matplotlib.pyplot as plt

# %% [markdown]
# #### 1.2.  Loading the data
# Your data comes from the [London Datastore](https://data.london.gov.uk/): a free, open-source data-sharing portal for London-oriented datasets.

# %%
# First, make a variable called url_LondonHousePrices, and assign it the following link, enclosed in quotation-marks as a string:
# https://data.london.gov.uk/download/uk-house-price-index/70ac0766-8902-4eb5-aab5-01951aaed773/UK%20House%20price%20index.xls

url_LondonHousePrices = "https://data.london.gov.uk/download/uk-house-price-index/70ac0766-8902-4eb5-aab5-01951aaed773/UK%20House%20price%20index.xls"

# The dataset we're interested in contains the Average prices of the houses, and is actually on a particular sheet of the Excel file. 
# As a result, we need to specify the sheet name in the read_excel() method.
# Put this data into a variable called properties.  
properties_raw = pd.read_excel(url_LondonHousePrices, sheet_name='Average price', index_col= None)

# %% [markdown]
# ### 2. Cleaning, transforming, and visualizing
# This second stage is arguably the most important part of any Data Science project. The first thing to do is take a proper look at the data. Cleaning forms the majority of this stage, and can be done both before or after Transformation.
#
# The end goal of data cleaning is to have tidy data. When data is tidy:
#
# 1. Each variable has a column.
# 2. Each observation forms a row.
#
# Keep the end goal in mind as you move through this process, every step will take you closer.
#
#
#
# ***Hint:*** This part of the data science pipeline should test those skills you acquired in:
# - Intermediate Python for data science, all modules.
# - pandas Foundations, all modules.
# - Manipulating DataFrames with pandas, all modules.
# - Data Types for Data Science, Module Four.
# - Python Data Science Toolbox - Part One, all modules

# %% [markdown]
# **2.1. Exploring your data**
#
# Think about your pandas functions for checking out a dataframe.

# %%
properties_raw.head(5)
# Out:
#   Unnamed: 0 City of London Barking & Dagenham       Barnet       Bexley  \
# 0        NaT      E09000001          E09000002    E09000003    E09000004
# 1 1995-01-01    91448.98487         50460.2266  93284.51832  64958.09036
# 2 1995-02-01    82202.77314        51085.77983  93190.16963  64787.92069
# 3 1995-03-01    79120.70256        51268.96956  92247.52435  64367.49344
# 4 1995-04-01    77101.20804        53133.50526  90762.87492  64277.66881
#
#          Brent      Bromley       Camden      Croydon       Ealing  ...  \
# 0    E09000005    E09000006    E09000007    E09000008    E09000009  ...
# 1  71306.56698  81671.47692  120932.8881  69158.16225  79885.89069  ...
# 2  72022.26197  81657.55944  119508.8622  68951.09542  80897.06551  ...
# 3  72015.76274  81449.31143  120282.2131  68712.44341  81379.86288  ...
# 4  72965.63094  81124.41227   120097.899  68610.04641  82188.90498  ...
#
#     NORTH WEST YORKS & THE HUMBER EAST MIDLANDS WEST MIDLANDS EAST OF ENGLAND  \
# ...

# %%
properties_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 317 entries, 0 to 316
# Data columns (total 49 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unnamed: 0            316 non-null    datetime64[ns]
#  1   City of London        317 non-null    object
#  2   Barking & Dagenham    317 non-null    object
#  3   Barnet                317 non-null    object
#  4   Bexley                317 non-null    object
#  5   Brent                 317 non-null    object
#  6   Bromley               317 non-null    object
#  7   Camden                317 non-null    object
#  8   Croydon               317 non-null    object
#  9   Ealing                317 non-null    object
#  10  Enfield               317 non-null    object
#  11  Greenwich             317 non-null    object
#  12  Hackney               317 non-null    object
#  13  Hammersmith & Fulham  317 non-null    object
# ...

# %%
properties_raw.shape
# Out:
# (317, 49)

# %%
properties_raw.describe()
# Out:
#        Unnamed: 34  Unnamed: 37  Unnamed: 47
# count          0.0          0.0          0.0
# mean           NaN          NaN          NaN
# std            NaN          NaN          NaN
# min            NaN          NaN          NaN
# 25%            NaN          NaN          NaN
# 50%            NaN          NaN          NaN
# 75%            NaN          NaN          NaN
# max            NaN          NaN          NaN

# %%
properties_raw.values
# Out:
# array([[NaT, 'E09000001', 'E09000002', ..., 'E12000009', nan,
#         'E92000001'],
#        [Timestamp('1995-01-01 00:00:00'), 91448.98487, 50460.2266, ...,
#         54705.1579, nan, 53202.77128],
#        [Timestamp('1995-02-01 00:00:00'), 82202.77314, 51085.77983, ...,
#         54356.14843, nan, 53096.1549],
#        ...,
#        [Timestamp('2021-02-01 00:00:00'), 741900.0531, 313825.9102, ...,
#         280373.0636, nan, 269615.4026],
#        [Timestamp('2021-03-01 00:00:00'), 742627.5735, 315750.633, ...,
#         286566.349, nan, 273485.5138],
#        [Timestamp('2021-04-01 00:00:00'), 793431.7231, 312287.8094, ...,
#         279951.0283, nan, 268379.638]], dtype=object)

# %%
properties_raw.columns
# Out:
# Index(['Unnamed: 0', 'City of London', 'Barking & Dagenham', 'Barnet',
#        'Bexley', 'Brent', 'Bromley', 'Camden', 'Croydon', 'Ealing', 'Enfield',
#        'Greenwich', 'Hackney', 'Hammersmith & Fulham', 'Haringey', 'Harrow',
#        'Havering', 'Hillingdon', 'Hounslow', 'Islington',
#        'Kensington & Chelsea', 'Kingston upon Thames', 'Lambeth', 'Lewisham',
#        'Merton', 'Newham', 'Redbridge', 'Richmond upon Thames', 'Southwark',
#        'Sutton', 'Tower Hamlets', 'Waltham Forest', 'Wandsworth',
#        'Westminster', 'Unnamed: 34', 'Inner London', 'Outer London',
#        'Unnamed: 37', 'NORTH EAST', 'NORTH WEST', 'YORKS & THE HUMBER',
#        'EAST MIDLANDS', 'WEST MIDLANDS', 'EAST OF ENGLAND', 'LONDON',
#        'SOUTH EAST', 'SOUTH WEST', 'Unnamed: 47', 'England'],
#       dtype='object')

# %%
properties_raw.index
# Out:
# RangeIndex(start=0, stop=317, step=1)

# %% [markdown]
# **2.2. Cleaning the data**
#
# You might find you need to transpose your dataframe, check out what its row indexes are, and reset the index. You  also might find you need to assign the values of the first row to your column headings  . (Hint: recall the .columns feature of DataFrames, as well as the iloc[] method).
#
# Don't be afraid to use StackOverflow for help  with this.

# %%
#transpose dataframe
properties= properties_raw.transpose()
properties
# Out:
#                             0                    1                    2    \
# Unnamed: 0                  NaT  1995-01-01 00:00:00  1995-02-01 00:00:00
# City of London        E09000001          91448.98487          82202.77314
# Barking & Dagenham    E09000002           50460.2266          51085.77983
# Barnet                E09000003          93284.51832          93190.16963
# Bexley                E09000004          64958.09036          64787.92069
# Brent                 E09000005          71306.56698          72022.26197
# Bromley               E09000006          81671.47692          81657.55944
# Camden                E09000007          120932.8881          119508.8622
# Croydon               E09000008          69158.16225          68951.09542
# Ealing                E09000009          79885.89069          80897.06551
# Enfield               E09000010          72514.69096          73155.19746
# Greenwich             E09000011          62300.10169          60993.26863
# ...

# %%
#reset the index 
properties = properties.reset_index()

# %%
properties
# Out:
#                    index          0                    1                    2  \
# 0             Unnamed: 0        NaT  1995-01-01 00:00:00  1995-02-01 00:00:00
# 1         City of London  E09000001          91448.98487          82202.77314
# 2     Barking & Dagenham  E09000002           50460.2266          51085.77983
# 3                 Barnet  E09000003          93284.51832          93190.16963
# 4                 Bexley  E09000004          64958.09036          64787.92069
# 5                  Brent  E09000005          71306.56698          72022.26197
# 6                Bromley  E09000006          81671.47692          81657.55944
# 7                 Camden  E09000007          120932.8881          119508.8622
# 8                Croydon  E09000008          69158.16225          68951.09542
# 9                 Ealing  E09000009          79885.89069          80897.06551
# 10               Enfield  E09000010          72514.69096          73155.19746
# ...

# %%
# assign the values of the first row to your column headings
properties.columns = properties.iloc[0]
properties.head(5)

# drop the the first row in which content is the same as the headings  
properties = properties.drop(properties.index[0])
properties
# Out:
# 0             Unnamed: 0        NaN 1995-01-01 00:00:00 1995-02-01 00:00:00  \
# 1         City of London  E09000001         91448.98487         82202.77314
# 2     Barking & Dagenham  E09000002          50460.2266         51085.77983
# 3                 Barnet  E09000003         93284.51832         93190.16963
# 4                 Bexley  E09000004         64958.09036         64787.92069
# 5                  Brent  E09000005         71306.56698         72022.26197
# 6                Bromley  E09000006         81671.47692         81657.55944
# 7                 Camden  E09000007         120932.8881         119508.8622
# 8                Croydon  E09000008         69158.16225         68951.09542
# 9                 Ealing  E09000009         79885.89069         80897.06551
# 10               Enfield  E09000010         72514.69096         73155.19746
# 11             Greenwich  E09000011         62300.10169         60993.26863
# ...

# %% [markdown]
# **2.3. Cleaning the data (part 2)**
#
# You might have to **rename** a couple columns. How do you do this? The clue's pretty bold...

# %%
#rename the first/second column 
properties= properties.rename(columns = {'Unnamed: 0':'borough', pd.NaT: 'ID'})
properties
#properties.columns.values[0]='borough'
# Out:
# 0                borough         ID 1995-01-01 00:00:00 1995-02-01 00:00:00  \
# 1         City of London  E09000001         91448.98487         82202.77314
# 2     Barking & Dagenham  E09000002          50460.2266         51085.77983
# 3                 Barnet  E09000003         93284.51832         93190.16963
# 4                 Bexley  E09000004         64958.09036         64787.92069
# 5                  Brent  E09000005         71306.56698         72022.26197
# 6                Bromley  E09000006         81671.47692         81657.55944
# 7                 Camden  E09000007         120932.8881         119508.8622
# 8                Croydon  E09000008         69158.16225         68951.09542
# 9                 Ealing  E09000009         79885.89069         80897.06551
# 10               Enfield  E09000010         72514.69096         73155.19746
# 11             Greenwich  E09000011         62300.10169         60993.26863
# ...

# %%
#check missing data 
properties.isna().any()
# Out:
# 0
# borough                False
# ID                      True
# 1995-01-01 00:00:00     True
# 1995-02-01 00:00:00     True
# 1995-03-01 00:00:00     True
#                        ...
# 2020-12-01 00:00:00     True
# 2021-01-01 00:00:00     True
# 2021-02-01 00:00:00     True
# 2021-03-01 00:00:00     True
# 2021-04-01 00:00:00     True
# Length: 318, dtype: bool

# %%
properties.isna().sum()
# Out:
# 0
# borough                0
# ID                     3
# 1995-01-01 00:00:00    3
# 1995-02-01 00:00:00    3
# 1995-03-01 00:00:00    3
#                       ..
# 2020-12-01 00:00:00    3
# 2021-01-01 00:00:00    3
# 2021-02-01 00:00:00    3
# 2021-03-01 00:00:00    3
# 2021-04-01 00:00:00    3
# Length: 318, dtype: int64

# %%
# subset the rows that are NAN 
nan_list=['Unnamed: 34','Unnamed: 37','Unnamed: 47']
properties[properties['borough'].isin(nan_list)]
# Out:
# 0       borough   ID 1995-01-01 00:00:00 1995-02-01 00:00:00  \
# 34  Unnamed: 34  NaN                 NaN                 NaN
# 37  Unnamed: 37  NaN                 NaN                 NaN
# 47  Unnamed: 47  NaN                 NaN                 NaN
#
# 0  1995-03-01 00:00:00 1995-04-01 00:00:00 1995-05-01 00:00:00  \
# 34                 NaN                 NaN                 NaN
# 37                 NaN                 NaN                 NaN
# 47                 NaN                 NaN                 NaN
#
# 0  1995-06-01 00:00:00 1995-07-01 00:00:00 1995-08-01 00:00:00  ...  \
# 34                 NaN                 NaN                 NaN  ...
# 37                 NaN                 NaN                 NaN  ...
# 47                 NaN                 NaN                 NaN  ...
#
# 0  2020-07-01 00:00:00 2020-08-01 00:00:00 2020-09-01 00:00:00  \
# 34                 NaN                 NaN                 NaN
# ...

# %%
#removing missing values since those unnamed rows are all NaN
properties = properties.dropna()
properties
# Out:
# 0                borough         ID 1995-01-01 00:00:00 1995-02-01 00:00:00  \
# 1         City of London  E09000001         91448.98487         82202.77314
# 2     Barking & Dagenham  E09000002          50460.2266         51085.77983
# 3                 Barnet  E09000003         93284.51832         93190.16963
# 4                 Bexley  E09000004         64958.09036         64787.92069
# 5                  Brent  E09000005         71306.56698         72022.26197
# 6                Bromley  E09000006         81671.47692         81657.55944
# 7                 Camden  E09000007         120932.8881         119508.8622
# 8                Croydon  E09000008         69158.16225         68951.09542
# 9                 Ealing  E09000009         79885.89069         80897.06551
# 10               Enfield  E09000010         72514.69096         73155.19746
# 11             Greenwich  E09000011         62300.10169         60993.26863
# ...

# %%
properties.columns
# Out:
# Index([          'borough',                'ID', 1995-01-01 00:00:00,
#        1995-02-01 00:00:00, 1995-03-01 00:00:00, 1995-04-01 00:00:00,
#        1995-05-01 00:00:00, 1995-06-01 00:00:00, 1995-07-01 00:00:00,
#        1995-08-01 00:00:00,
#        ...
#        2020-07-01 00:00:00, 2020-08-01 00:00:00, 2020-09-01 00:00:00,
#        2020-10-01 00:00:00, 2020-11-01 00:00:00, 2020-12-01 00:00:00,
#        2021-01-01 00:00:00, 2021-02-01 00:00:00, 2021-03-01 00:00:00,
#        2021-04-01 00:00:00],
#       dtype='object', name=0, length=318)

# %% [markdown]
# **2.4.Transforming the data**
#
# Remember what Wes McKinney said about tidy data?
#
# You might need to **melt** your DataFrame here.

# %%
properties_tall = properties.melt(id_vars=['borough','ID'],var_name=['time'], value_name='house_price')

# %% [markdown]
# Remember to make sure your column data types are all correct. Average prices, for example, should be floating point numbers...

# %%
properties_tall
# Out:
#                   borough         ID       time  house_price
# 0          City of London  E09000001 1995-01-01  91448.98487
# 1      Barking & Dagenham  E09000002 1995-01-01   50460.2266
# 2                  Barnet  E09000003 1995-01-01  93284.51832
# 3                  Bexley  E09000004 1995-01-01  64958.09036
# 4                   Brent  E09000005 1995-01-01  71306.56698
# ...                   ...        ...        ...          ...
# 14215     EAST OF ENGLAND  E12000006 2021-04-01  313964.3201
# 14216              LONDON  E12000007 2021-04-01  491686.8085
# 14217          SOUTH EAST  E12000008 2021-04-01  341358.4469
# 14218          SOUTH WEST  E12000009 2021-04-01  279951.0283
# 14219             England  E92000001 2021-04-01   268379.638
#
# [14220 rows x 4 columns]

# %%
#convert object to float for house price data 
properties_tall['house_price'] = properties_tall['house_price'].astype(float)
properties_tall.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14220 entries, 0 to 14219
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   borough      14220 non-null  object
#  1   ID           14220 non-null  object
#  2   time         14220 non-null  datetime64[ns]
#  3   house_price  14220 non-null  float64
# dtypes: datetime64[ns](1), float64(1), object(2)
# memory usage: 444.5+ KB

# %% [markdown]
# **2.5. Cleaning the data (part 3)**
#
# Do we have an equal number of observations in the ID, Average Price, Month, and London Borough columns? Remember that there are only 32 London Boroughs. How many entries do you have in that column?
#
# Check out the contents of the London Borough column, and if you find null values, get rid of them however you see fit.

# %%
#check how many of the boroughs are there 
properties_tall['borough'].value_counts()
# Out:
# Redbridge               316
# Barking & Dagenham      316
# Tower Hamlets           316
# EAST OF ENGLAND         316
# Unnamed: 34             316
# Wandsworth              316
# NORTH WEST              316
# England                 316
# Camden                  316
# Bexley                  316
# Richmond upon Thames    316
# Lewisham                316
# Greenwich               316
# Haringey                316
# Westminster             316
# Kingston upon Thames    316
# Inner London            316
# Hounslow                316
# Enfield                 316
# Waltham Forest          316
# Unnamed: 47             316
# Bromley                 316
# EAST MIDLANDS           316
# City of London          316
# Outer London            316
# Havering                316
# Barnet                  316
# Hillingdon              316
# Ealing                  316
# SOUTH WEST              316
# Islington               316
# Southwark               316
# WEST MIDLANDS           316
# ...

# %%
print(properties_tall.nunique())
#45 boroughs are found.
# Out:
# borough           45
# ID                45
# time             316
# house_price    14220
# dtype: int64

# %%
## A list of non-boroughs. 
nonboroughs = ['Inner London', 'Outer London', 
               'NORTH EAST', 'NORTH WEST', 'YORKS & THE HUMBER', 
               'EAST MIDLANDS', 'WEST MIDLANDS',
              'EAST OF ENGLAND', 'LONDON', 'SOUTH EAST', 
              'SOUTH WEST', 'England']

# %%
# Get names of indexes for which column is in nonboroughs list
indexNames = properties_tall[properties_tall['borough'].isin(nonboroughs)].index

# Delete these row indexes from dataFrame
properties_tall.drop(indexNames , inplace=True)
print(properties_tall.nunique())
# Out:
# borough           33
# ID                33
# time             316
# house_price    10428
# dtype: int64

# %%
#assign to a new DataFrame: df, final-stage DataFrame that's ready for analysis
df = properties_tall
df.head()
df = df.sort_values(by=['ID','time'],ascending=True)
df = df.reset_index(drop=True)
df.head()
# Out:
#           borough         ID       time  house_price
# 0  City of London  E09000001 1995-01-01  91448.98487
# 1  City of London  E09000001 1995-02-01  82202.77314
# 2  City of London  E09000001 1995-03-01  79120.70256
# 3  City of London  E09000001 1995-04-01  77101.20804
# 4  City of London  E09000001 1995-05-01  84409.14932

# %% [markdown]
# **2.6. Visualizing the data**
#
# To visualize the data, why not subset on a particular London Borough? Maybe do a line plot of Month against Average Price?

# %%
#subset City of London and do a line plot of year againt house price 
df[df['borough']=='City of London'].plot(x='time',y='house_price',kind='line')
plt.show()

# %% [markdown]
# To limit the number of data points you have, you might want to extract the year from every month value your *Month* column.
#
# To this end, you *could* apply a ***lambda function***. Your logic could work as follows:
# 1. look through the `Month` column
# 2. extract the year from each individual value in that column
# 3. store that corresponding year as separate column.
#
# Whether you go ahead with this is up to you. Just so long as you answer our initial brief: which boroughs of London have seen the greatest house price increase, on average, over the past two decades?

# %%
df['year'] = df['time'].apply(lambda t: t.year)
df
# Out:
#               borough         ID       time   house_price  year
# 0      City of London  E09000001 1995-01-01   91448.98487  1995
# 1      City of London  E09000001 1995-02-01   82202.77314  1995
# 2      City of London  E09000001 1995-03-01   79120.70256  1995
# 3      City of London  E09000001 1995-04-01   77101.20804  1995
# 4      City of London  E09000001 1995-05-01   84409.14932  1995
# ...               ...        ...        ...           ...   ...
# 10423     Westminster  E09000033 2020-12-01  916413.89420  2020
# 10424     Westminster  E09000033 2021-01-01  949115.37140  2021
# 10425     Westminster  E09000033 2021-02-01  952620.10810  2021
# 10426     Westminster  E09000033 2021-03-01  936835.78210  2021
# 10427     Westminster  E09000033 2021-04-01  918858.42530  2021
#
# [10428 rows x 5 columns]

# %% [markdown]
# **3. Modeling**
#
# Consider creating a function that will calculate a ratio of house prices, comparing the price of a house in 2018 to the price in 1998.
#
# Consider calling this function create_price_ratio.
#
# You'd want this function to:
# 1. Take a filter of dfg, specifically where this filter constrains the London_Borough, as an argument. For example, one admissible argument should be: dfg[dfg['London_Borough']=='Camden'].
# 2. Get the Average Price for that Borough, for the years 1998 and 2018.
# 4. Calculate the ratio of the Average Price for 1998 divided by the Average Price for 2018.
# 5. Return that ratio.
#
# Once you've written this function, you ultimately want to use it to iterate through all the unique London_Boroughs and work out the ratio capturing the difference of house prices between 1998 and 2018.
#
# Bear in mind: you don't have to write a function like this if you don't want to. If you can solve the brief otherwise, then great!
#
# ***Hint***: This section should test the skills you acquired in:
# - Python Data Science Toolbox - Part One, all modules

# %%
#calculate the average house price for each year and save it to a new dataframe 
dfg = df.groupby(['year','borough']).mean()
dfg = dfg.reset_index()
dfg[dfg['year']==1996]
# Out:
#     year               borough    house_price
# 33  1996    Barking & Dagenham   51718.192690
# 34  1996                Barnet   94000.445448
# 35  1996                Bexley   65490.417234
# 36  1996                 Brent   75235.918367
# 37  1996               Bromley   83547.483632
# 38  1996                Camden  133810.487933
# 39  1996        City of London  105651.057557
# 40  1996               Croydon   69713.920086
# 41  1996                Ealing   83389.914491
# 42  1996               Enfield   74062.012957
# 43  1996             Greenwich   65186.781770
# 44  1996               Hackney   69247.652452
# 45  1996  Hammersmith & Fulham  132045.188025
# 46  1996              Haringey   84501.247705
# 47  1996                Harrow   85926.701202
# 48  1996              Havering   69347.956902
# 49  1996            Hillingdon   75753.415728
# 50  1996              Hounslow   73886.734233
# 51  1996             Islington   97069.716409
# ...

# %%
idx = dfg.groupby(['year'])['house_price'].transform(max) == dfg['house_price']
dfg[idx]
# Out:
#      year               borough   house_price
# 19   1995  Kensington & Chelsea  1.928573e+05
# 52   1996  Kensington & Chelsea  2.071567e+05
# 85   1997  Kensington & Chelsea  2.466556e+05
# 118  1998  Kensington & Chelsea  2.683501e+05
# 151  1999  Kensington & Chelsea  3.114554e+05
# 184  2000  Kensington & Chelsea  3.768022e+05
# 217  2001  Kensington & Chelsea  4.201295e+05
# 250  2002  Kensington & Chelsea  4.603825e+05
# 283  2003  Kensington & Chelsea  4.604906e+05
# 316  2004  Kensington & Chelsea  5.121867e+05
# 349  2005  Kensington & Chelsea  5.202062e+05
# 382  2006  Kensington & Chelsea  5.980075e+05
# 415  2007  Kensington & Chelsea  7.466792e+05
# 448  2008  Kensington & Chelsea  7.848347e+05
# 481  2009  Kensington & Chelsea  7.051875e+05
# 514  2010  Kensington & Chelsea  8.373150e+05
# 547  2011  Kensington & Chelsea  9.085651e+05
# 580  2012  Kensington & Chelsea  1.009045e+06
# 613  2013  Kensington & Chelsea  1.126573e+06
# ...

# %%
def create_price_ratio(d):
    y1998 = float(d['house_price'][d['year']==1998])
    y2018 = float(d['house_price'][d['year']==2018])
    ratio = [y2018/y1998]
    return ratio

# %%
#  Test out the function by calling it with the following argument:
# dfg[dfg['London_Borough']=='Barking & Dagenham']
create_price_ratio(dfg[dfg['borough']=='Barking & Dagenham'])
# Out:
# [4.89661861291754]

# %%
final = {}
for i in dfg['borough'].unique(): 
    bo = dfg[dfg['borough']==i]
    final[i] = create_price_ratio(bo)  
final
# Out:
# {'Barking & Dagenham': [4.89661861291754],
#  'Barnet': [4.358195917538044],
#  'Bexley': [4.248977046127877],
#  'Brent': [4.8945544971392865],
#  'Bromley': [4.0947846853338765],
#  'Camden': [4.935353408884261],
#  'City of London': [5.301620377587609],
#  'Croydon': [4.201100280024767],
#  'Ealing': [4.311450902121834],
#  'Enfield': [4.26347158349581],
#  'Greenwich': [4.763036347329193],
#  'Hackney': [6.198285561008662],
#  'Hammersmith & Fulham': [4.137798101936229],
#  'Haringey': [5.134624964136042],
#  'Harrow': [4.0591964329643195],
#  'Havering': [4.325230371335308],
#  'Hillingdon': [4.2002730803844575],
#  'Hounslow': [3.976409106143329],
#  'Islington': [4.844048012802298],
#  'Kensington & Chelsea': [5.082465066092464],
#  'Kingston upon Thames': [4.270549521484271],
#  'Lambeth': [4.957751163514063],
#  'Lewisham': [5.449221041059685],
#  'Merton': [4.741273313294604],
#  'Newham': [5.305390437201879],
#  'Redbridge': [4.471182006097364],
# ...

# %%
df_final_d = pd.DataFrame(final)
df_final_d
# Out:
#    Barking & Dagenham    Barnet    Bexley     Brent   Bromley    Camden  \
# 0            4.896619  4.358196  4.248977  4.894554  4.094785  4.935353
#
#    City of London  Croydon    Ealing   Enfield  ...    Merton   Newham  \
# 0         5.30162   4.2011  4.311451  4.263472  ...  4.741273  5.30539
#
#    Redbridge  Richmond upon Thames  Southwark    Sutton  Tower Hamlets  \
# 0   4.471182              4.005162   5.516485  4.118523       4.626701
#
#    Waltham Forest  Wandsworth  Westminster
# 0        5.834756    4.757709     5.353565
#
# [1 rows x 33 columns]

# %%
#transpose and rename the columns 
df_final = df_final_d.T
df_final = df_final.reset_index()
df_final = df_final.rename(columns={'index':'borough',0:'ratio_2018_1998'})
df_final
# Out:
#                  borough  ratio_2018_1998
# 0     Barking & Dagenham         4.896619
# 1                 Barnet         4.358196
# 2                 Bexley         4.248977
# 3                  Brent         4.894554
# 4                Bromley         4.094785
# 5                 Camden         4.935353
# 6         City of London         5.301620
# 7                Croydon         4.201100
# 8                 Ealing         4.311451
# 9                Enfield         4.263472
# 10             Greenwich         4.763036
# 11               Hackney         6.198286
# 12  Hammersmith & Fulham         4.137798
# 13              Haringey         5.134625
# 14                Harrow         4.059196
# 15              Havering         4.325230
# 16            Hillingdon         4.200273
# 17              Hounslow         3.976409
# 18             Islington         4.844048
# 19  Kensington & Chelsea         5.082465
# 20  Kingston upon Thames         4.270550
# ...

# %%
#which boroughs of London have seen the greatest house price increase, on average, over the past two decades?
#sort the dataframe 
df_final = df_final.sort_values('ratio_2018_1998', ascending=False)
df_final
# Out:
#                  borough  ratio_2018_1998
# 11               Hackney         6.198286
# 30        Waltham Forest         5.834756
# 27             Southwark         5.516485
# 22              Lewisham         5.449221
# 32           Westminster         5.353565
# 24                Newham         5.305390
# 6         City of London         5.301620
# 13              Haringey         5.134625
# 19  Kensington & Chelsea         5.082465
# 21               Lambeth         4.957751
# 5                 Camden         4.935353
# 0     Barking & Dagenham         4.896619
# 3                  Brent         4.894554
# 18             Islington         4.844048
# 10             Greenwich         4.763036
# 31            Wandsworth         4.757709
# 23                Merton         4.741273
# 29         Tower Hamlets         4.626701
# 25             Redbridge         4.471182
# 1                 Barnet         4.358196
# 15              Havering         4.325230
# ...

# %%
# Summary statistics 
#avg = df_final['ratio_2018_1998'].mean()
print('Mean of housing price increase (1998-2018) in London is:', df_final['ratio_2018_1998'].mean()) 
print('Median of housing price increase in London (1998-2018) is:', df_final['ratio_2018_1998'].median()) 
print('SD of housing price increase in London (1998-2018) is:', df_final['ratio_2018_1998'].std())
# Out:
# Mean of housing price increase (1998-2018) in London is: 4.716235249525991
# Median of housing price increase in London (1998-2018) is: 4.741273313294604
# SD of housing price increase in London (1998-2018) is: 0.571488757685576

# %%
# the top 15 
london_15 = df_final.head(15)
london_1

# %%
london_bar = london_15.set_index('borough')
london_bar.plot(kind='bar',title="Top 15 boroughs' house price increases in London")
plt.show()

# %% [markdown]
# ### 4. Conclusion
# What can you conclude? Type out your conclusion below.
#
# Look back at your notebook. Think about how you might summarize what you have done, and prepare a quick presentation on it to your mentor at your next meeting.
#
# We hope you enjoyed this practical project. It should have consolidated your data hygiene and pandas skills by looking at a real-world problem involving just the kind of dataset you might encounter as a budding data scientist. Congratulations, and looking forward to seeing you at the next step in the course!

# %% [markdown]
# # Findings:
# #1 Hackney borough has seen the greatest house price increase in the past two decades.
# The average house price in Hackeny is 6.2 times the house price in 1998.
# #2 Hounslow borough has the smallest housing price increase compared to the price in 1998, only increased nearly 4 times compared to 1998.
# #3 The average increase of house price among 32 boroughs in London is 4.72 times
# #4 Median of housing price increase in London (1998-2018) is: 4.74 times
# #5 Standard deviation of housing price increase in London (1998-2018) is: 0.57
